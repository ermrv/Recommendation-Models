# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline
plt.style.use("ggplot")

import sklearn
from sklearn.decomposition import TruncatedSVD

# %%
dataset = pd.read_csv('/content/ratings_Beauty.csv')
dataset =dataset.dropna()

# %%
data = dataset.head(10000)
ratings_utility_matrix = data.pivot_table(values='Rating', index='UserId', columns='ProductId', fill_value=0)
ratings_utility_matrix.head()
# Out:
# ProductId              0205616461  0558925278  ...  B000052YQ0  B000052YQ2
# UserId                                         ...
# A00205921JHJK5X9LNP42           0           0  ...           0           0
# A024581134CV80ZBLIZTZ           0           0  ...           0           0
# A03056581JJIOL5FSKJY7           0           0  ...           0           0
# A03099101ZRK4K607JVHH           0           0  ...           0           0
# A0505229A7NSH3FRXRR4            0           0  ...           0           0
#
# [5 rows x 886 columns]

# %%
X = ratings_utility_matrix.T
X.head()
# Out:
# UserId      A00205921JHJK5X9LNP42  ...  AZZTJQ7CQZUD8
# ProductId                          ...
# 0205616461                      0  ...              0
# 0558925278                      0  ...              0
# 0733001998                      0  ...              0
# 0737104473                      0  ...              0
# 0762451459                      0  ...              0
#
# [5 rows x 9697 columns]

# %%
SVD = TruncatedSVD(n_components=10)
decomposed_matrix = SVD.fit_transform(X)
decomposed_matrix.shape
# Out:
# (886, 10)

# %%
correlation_matrix = np.corrcoef(decomposed_matrix)
correlation_matrix.shape
# Out:
# (886, 886)

# %%
product_bought_id ="6117036094"

product_names = list(X.index)
product_ID = product_names.index(product_bought_id)
product_ID
# Out:
# 99

# %%
correlation_product_ID = correlation_matrix[product_ID]
correlation_product_ID.shape
# Out:
# (886,)

# %%
Recommend = list(X.index[correlation_product_ID > 0.90])

# Removes the item already bought by the customer
Recommend.remove(product_bought_id) 

Recommend[0:9]
# Out:
# ['9601403825',
#  '9759091062',
#  '9790784120',
#  '9790784414',
#  '9790784856',
#  '9790790074',
#  '9790793626',
#  '9790793871',
#  '979079567X']
